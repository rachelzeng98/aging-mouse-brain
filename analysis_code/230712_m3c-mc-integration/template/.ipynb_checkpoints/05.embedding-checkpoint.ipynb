# %%
import matplotlib.pyplot as plt

from ALLCools.clustering import tsne
from ALLCools.plot import *
from ALLCools.integration import SeuratIntegration
from wmb import brain

import scanpy as sc
import anndata
from harmonypy import run_harmony

# %% [markdown]
# ## Parameters

# %%
# Parameters
categorical_key = ['new_celltypes_0808']
ref_dataset = "mc"
cpu = 5
group_name = "ALL"
mem_gb = 1
resolution = 0.5

# %% [markdown]
# ## Load

# %%
adata_merge = anndata.read_h5ad('final.h5ad')
adata_merge
# Out:
# AnnData object with n_obs × n_vars = 18044 × 1328
#     obs: 'Modality', 'new_celltypes_0808'
#     var: 'chrom', 'cef', 'end-m3C', 'start-m3C', 'bin_start-mC', 'bin_end-mC'
#     obsm: 'X_pca_integrate'

# %% [markdown]
# ## Harmony for embedding

# %%
# 30 mins to run 4M + 3K cell

ho = run_harmony(data_mat=adata_merge.obsm['X_pca_integrate'],
                 meta_data=adata_merge.obs,
                 nclust=50,
                 vars_use=['Modality'], 
                 max_iter_harmony=30)
# Out:
# 2023-08-14 21:27:31,450 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2023-08-14 21:27:33,134 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2023-08-14 21:27:33,177 - harmonypy - INFO - Iteration 1 of 30
# 2023-08-14 21:27:34,396 - harmonypy - INFO - Iteration 2 of 30
# 2023-08-14 21:27:35,525 - harmonypy - INFO - Iteration 3 of 30
# 2023-08-14 21:27:35,994 - harmonypy - INFO - Iteration 4 of 30
# 2023-08-14 21:27:36,531 - harmonypy - INFO - Iteration 5 of 30
# 2023-08-14 21:27:36,991 - harmonypy - INFO - Iteration 6 of 30
# 2023-08-14 21:27:37,460 - harmonypy - INFO - Iteration 7 of 30
# 2023-08-14 21:27:37,866 - harmonypy - INFO - Iteration 8 of 30
# 2023-08-14 21:27:38,214 - harmonypy - INFO - Iteration 9 of 30
# 2023-08-14 21:27:38,559 - harmonypy - INFO - Converged after 9 iterations

# %%
adata_merge.obsm['X_harmony'] = ho.Z_corr.T

# %% [markdown]
# ### TSNE

# %%
# 1 hour to run 4M + 3K cell
tsne(adata_merge, obsm='X_harmony')

# %% [markdown]
# ### UMAP

# %%
# 15 min to run 4M + 3K cell
sc.pp.neighbors(adata_merge, use_rep='X_harmony')

# %%
# 2 hours to run 4M + 3K cell
sc.tl.leiden(adata_merge, resolution=resolution)

# %%
# 2 hours to run 4M + 3K cell
# 4 hours to run 4M + 3K cell if using spectral init, the init step is very slow
min_dist = max(0.1, 1 - adata_merge.shape[0] / 60000)
try:
    sc.tl.paga(adata_merge, groups='leiden')
    sc.pl.paga(adata_merge, plot=False)
    sc.tl.umap(adata_merge, min_dist=min_dist, init_pos='paga')
except Exception:
    print('Init with PAGA failed, use default spectral init')
    sc.tl.umap(adata_merge, min_dist=min_dist)

# %% [markdown]
# ## Plot

# %%
mc_data = adata_merge[adata_merge.obs['Modality'] == 'mC']
m3c_data = adata_merge[adata_merge.obs['Modality'] == 'm3C']

# %%
for coord_base in ['tsne', 'umap']:
    fig, axes = plt.subplots(nrows=1,
                             ncols=2,
                             figsize=(6, 3),
                             dpi=200,
                             constrained_layout=True)
    
    ax = axes[0]
    categorical_scatter(data=m3c_data,
                        coord_base=coord_base,
                        max_points=None,
                        hue=None,
                        scatter_kws=dict(color='lightgrey'),
                        ax=ax)
    categorical_scatter(
        data=mc_data,
        ax=ax,
        coord_base=coord_base,
        hue='leiden',
        text_anno='leiden',
        palette='tab20',
        max_points=None,
    )
    ax.set_title('mc cells')
    
    ax = axes[1]
    categorical_scatter(data=mc_data,
                        coord_base=coord_base,
                        max_points=None,
                        hue=None,
                        scatter_kws=dict(color='lightgrey'),
                        ax=ax)
    categorical_scatter(
        data=m3c_data,
        ax=ax,
        coord_base=coord_base,
        hue='leiden',
        text_anno='leiden',
        palette='tab20',
        max_points=None,
    )
    ax.set_title('m3c cells')

# %% [markdown]
# ## Save

# %%
adata_merge.write_h5ad('final_with_coords.h5ad')

# %%
adata_merge
# Out:
# AnnData object with n_obs × n_vars = 205413 × 5302
#     obs: 'CellType', 'Modality', 'leiden'
#     var: 'chrom', 'cef', 'end-m3C', 'start-m3C', 'bin_start-mC', 'bin_end-mC'
#     uns: 'neighbors', 'leiden', 'paga', 'leiden_sizes', 'umap'
#     obsm: 'X_pca_integrate', 'X_harmony', 'X_tsne', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
import subprocess
subprocess.run(['rm', '-f', 'final.h5ad'])
# Out:
# CompletedProcess(args=['rm', '-f', 'final.h5ad'], returncode=0)

# %%
adata_merge.obs.to_csv('mC-m3C-integration.csv')
