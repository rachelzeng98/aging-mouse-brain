# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import anndata
import scanpy as sc
from glob import glob
import time
from scipy.stats import spearmanr, pearsonr
from itertools import cycle, islice
mpl.style.use('default')
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
# mpl.rcParams['font.family'] = 'sans-serif'
# mpl.rcParams['font.sans-serif'] = 'Helvetica'
from matplotlib.backends.backend_pdf import PdfPages
from amb import *
import matplotlib.patches as patches
from scipy.stats import zscore

# %%
colordict = get_age_palette()
colordict['8wk'] = colordict['2mo']

# %%
indir = 'gen_contact_decay/'
meta = pd.read_csv('/data/metadata/m3C_META_230814.csv', index_col = 0)
meta['Cis/Trans'] = meta['TotalCisContacts']/meta['TotalTransContacts']
decay = pd.concat([pd.read_hdf(xx, key='data') for xx in glob(f'{indir}/pool_*/*.contact_distance_decay.hdf5')], axis=0)

# %%
shared_cells = list(set(meta.index) & set(decay.index))
decay = decay.loc[shared_cells].copy()
meta = meta.loc[shared_cells].copy()
len(shared_cells)
# Out:
# 72666

# %%
decay = decay / decay.sum(axis=1)[:,None]

# %%
count = meta['CellType'].value_counts()
meta = meta[meta['CellType'].isin(count.index[count>1000])]
meta.head()
# Out:
#                                        InputReadPairs  InputReadPairsBP  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4             2156445         652115819
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8         1962959         593956735
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15           2305710         696804608
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21          2251079         657829403
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16         1828415         534303806
#
#                                        TrimmedReadPairs  R1WithAdapters  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4               2156014             319
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8           1962666             191
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15             2305133             506
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21            2250325             587
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16           1827871             317
#
#                                        R1QualTrimBP  R1TrimmedReadsBP  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4            913662         273446091
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8        857037         249018344
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15         1187486         291920200
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21        1300474         273623055
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16        910645         222390277
#
#                                        R2WithAdapters  R2QualTrimBP  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4                1215        983127
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8             780        883579
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15              1432        937511
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21             1350       1190580
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16             850        797855
#
#                                        R2TrimmedReadsBP  UniqueMappedReads  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4             290462434            2072063
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8         264648794            1832333
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15           310462394            2321219
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21          291604411            2242393
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16         237023348            2074220
#
#                                        ...   Age  CEMBARegion  \
# cell                                   ...
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4      ...   8wk        5E+6E
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8  ...   9mo     7H+8H+9G
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15    ...   8wk        2A+3A
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21   ...   8wk      13D+14C
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16  ...  18mo      12D+13B
#
#                                         DissectionRegion             Region  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4              CP-2+CP-3    Caudate_Putamen
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8  AMY-1+AMY-2+AMY-3           Amygdala
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15          PFC-1+PFC-2     Frontal_Cortex
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21           PAG-2+PCG            PAG-PCG
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16        RHP-3+RHP-5  Entorhinal_Cortex
#
#                                        Replicate  l1  mc_m3c-co_cluster_l1  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4           rep1   5                    17
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8       rep2  20                    14
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15         rep2  23                     5
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21        rep1   4                     1
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16       rep2   3                     4
#
#                                        mc_m3c-co_cluster_l2        CellType  \
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4                       4-3    Microglia NN
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8                   2-6    MEA-COA Glut
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15                     1-6  L6 IT CTX Glut
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21                    6-7        Oligo NN
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16                   2-0        Astro NN
#
#                                        Cis/Trans
# cell
# AMB_220503_8wk_5E_6E_2_P2-2-E5-I4       1.297836
# AMB_220524_9mo_7H_8H_9G_1_P4-4-I15-D8   0.740017
# AMB_220517_8wk_2A_3A_2_P1-2-M14-N15     1.534896
# AMB_220428_8wk_13D_14C_1_P7-5-H6-K21    1.322225
# AMB_220616_18mo_12D_13B_1_P2-2-I2-I16   1.564990
#
# [5 rows x 60 columns]

# %%
meta['short'] = decay.loc[:, (decay.columns > 50) & (decay.columns < 77)].mean(axis=1)
meta['long'] = decay.loc[:, (decay.columns > 103) & (decay.columns < 114)].mean(axis=1)
meta['ratio'] = np.log2(meta['short'] / meta['long'])

# %% [markdown]
# ## plot celltype decay

# %%
with PdfPages('CellType.contact_distance.pdf') as pdf:
    for plot_celltype in all_celltypes:
        #selc = meta[meta['CellType'].isin([plot_celltype])].sort_values('ratio').index
        selc = meta[meta['CellType'].isin([plot_celltype])].index
        tmp = meta.loc[selc,:]
        # tmp = pd.concat([tmp[tmp[hue]==xx] for xx in age_groups], axis=0)
        to_plot = decay.loc[tmp.index].copy()
        

        offset = [0]
        count = tmp[hue].value_counts().loc[age_groups].values
        for i in range(len(age_groups)):
            offset.append(offset[-1]+count[i])

        offset = np.array(offset)

        fig, axes = plt.subplots(4, 1, 
                                 gridspec_kw={'height_ratios': [20,1,1,1]},
                                 figsize=(5,3), 
                                 sharex='all',dpi = 200,
                                constrained_layout = True)

        ax = axes[0]
        ax.imshow(zscore(to_plot, axis=1).T, cmap='Blues', aspect='auto', interpolation='none', vmin=-2)
        ax.set_xticks([])
        ax.set_yticks([np.log2(xx/2500)/0.125 for xx in [5000, 20000, 100000, 500000, 2000000, 10000000, 50000000]])
        ax.set_yticklabels(['5k', '20k', '100k', '500k', '2M', '10M', '50M'])

        ax = axes[1]
        ax.axis('off')
        for i,label in enumerate(age_groups):
            rect = patches.Rectangle((offset[i], 0), offset[i+1]-offset[i], 1, linewidth=0, edgecolor='none', facecolor=colordict[label])
            ax.add_patch(rect)

        ax = axes[2]
        ax.imshow(tmp['Cis/Trans'][None, :], cmap='viridis', aspect='auto',vmin=0.5,vmax=2, interpolation='none') #
        ax.axis('off')

        ax = axes[3]
        ax.imshow(tmp['ratio'][None, :], cmap='coolwarm', aspect='auto',interpolation='none') #
        ax.axis('off')

        for ax,xx in zip(axes, [f'{plot_celltype} Contact Distance', 'Age', 'Cis/Trans','log2 Short/Long']):
            ax.set_title(xx, fontsize=10)
        pdf.savefig(fig)
        plt.close()

# %% [markdown]
# ## plot boxplot

# %%
meta['Age.Rep'] = meta['Age'] + '.' + meta['Replicate']

# %%
x = 'CellType'
y = 'ratio'

hue = 'Age'
hue_order = ['8wk','9mo','18mo']

# %%
order = meta.groupby(x)[y].mean().sort_values().index

# %%
meta[x] = pd.Categorical(meta[x],
                      categories=order,
                      ordered=True)
meta.sort_values(x, inplace=True)

# %%
hue = 'Age.Rep'
hue_order = ['8wk.rep1','8wk.rep2','9mo.rep1','9mo.rep2','18mo.rep1','18mo.rep2']

age_rep_palette = {'8wk.rep1':colordict['8wk'],'8wk.rep2':colordict['8wk'],
                   '9mo.rep1':colordict['9mo'],'9mo.rep2':colordict['9mo'],
                   '18mo.rep1':colordict['18mo'],'18mo.rep2':colordict['18mo']}

# %%
fig, ax = plt.subplots(figsize = (10,5), dpi = 200)
sns.boxplot(data=meta, 
            ax = ax, 
            x=x, y=y, 
            hue=hue,
            linewidth=0.5,
            hue_order = hue_order,
            palette=age_rep_palette,
            showfliers=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_ylim(-2,1.5)
ax.set_ylabel('log2 short/long ratio')
legend = ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()
